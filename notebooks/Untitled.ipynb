# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.random.randn(100)
y = np.random.randn(100)

# %%
plt.plot(x)
plt.plot(y)

# %%
import _ucrdtw
loc, dist = _ucrdtw.dtw(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3e46a456c652> in <module>()
#       1 import _ucrdtw
# ----> 2 loc, dist = _ucrdtw.dtw(x, y)
#
# AttributeError: module '_ucrdtw' has no attribute 'dtw'

# %%
loc
# Out:
# 0
